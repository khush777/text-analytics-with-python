# %% [markdown]
# <a href="https://colab.research.google.com/github/khush777/text-analytics-with-python/blob/master/Visualizing_Topic_Models_with_pyLDAvis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyLDAvis

# %%
import pyLDAvis
import pyLDAvis.sklearn
import dill
import warnings

warnings.filterwarnings('ignore')
pyLDAvis.enable_notebook()

# %%
with open('nmf_model.pkl', 'rb') as f:
    nmf_model = dill.load(f)
with open('cv_features.pkl', 'rb') as f:
    cv_features = dill.load(f)
with open('cv.pkl', 'rb') as f:
    cv = dill.load(f)

# %%
import pandas as pd
import numpy as np

top_terms = 20
TOTAL_TOPICS = 20
vocabulary = np.array(cv.get_feature_names())
topic_terms = nmf_model.components_
topic_key_term_idxs = np.argsort(-np.absolute(topic_terms), axis=1)[:, :top_terms]
topic_keyterms = vocabulary[topic_key_term_idxs]
topics = [', '.join(topic) for topic in topic_keyterms]
pd.set_option('display.max_colwidth', -1)
topics_df = pd.DataFrame(topics,
                         columns = ['Terms per Topic'],
                         index=['Topic'+str(t) for t in range(1, TOTAL_TOPICS+1)])
topics_df
# Out:
#                                                                                                                                                                                                                                   Terms per Topic
# Topic1   security, threat, phishing, employee, information security, behaviour, email, organisation, awareness, compliance, participant, information system, policy, influence, cyber, interview, breach, password, organization, security policy
# Topic2   neural, neural network, adversarial, weight, label, cnn, convolutional, dimension, robustness, pixel, deep learning, gradient, activation, neuron, trained, lstm, batch, prediction, confidence, train
# Topic3   game, player, ai, void, board, unity, agree, agent, playing, nation, mechanic, enemy, integer, participant, intuitive, character, prototype, planning, engine, network security
# ...

# %%
pyLDAvis.sklearn.prepare(nmf_model, cv_features, cv, mds='mmds')
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1      0.255213  0.002537  1       1        10.600774
# 17    -0.157131  0.089010  2       1        9.391591
# 13     0.081907  0.052401  3       1        7.486701
# 8      0.103456 -0.167103  4       1        7.366248
# 11     0.266662 -0.180507  5       1        6.050717
# 18     0.277114 -0.095361  6       1        5.771450
# 6      0.005209  0.329952  7       1        5.762659
# 19    -0.007879 -0.054493  8       1        5.655474
# 16    -0.094624 -0.086026  9       1        5.310365
# 2      0.180565  0.289862  10      1        5.030368
# 5      0.026045  0.151262  11      1        4.610501
# 3     -0.075672  0.218407  12      1        4.483868
# 14     0.023621 -0.317236  13      1        3.797653
# 10    -0.234413  0.280788  14      1        3.676156
# 15     0.158594 -0.289280  15      1        2.907818
# 9     -0.326705  0.134778  16      1        2.787134
# ...

# %%
pyLDAvis.sklearn.prepare(nmf_model, cv_features, cv, mds='tsne')
# Out:
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 1     -10.878068   10.538728   1       1        10.600774
# 17    -60.884026  -75.591820   2       1        9.391591
# 13    -2.336119   -53.289074   3       1        7.486701
# 8     -61.385319  -12.914634   4       1        7.366248
# 11    -28.737743   126.296997  5       1        6.050717
# 18     1.066606   -123.552811  6       1        5.771450
# 6      45.140720  -7.947869    7       1        5.762659
# 19    -140.795975 -98.530548   8       1        5.655474
# 16     61.531681  -83.240562   9       1        5.310365
# 2     -72.563057  -140.396881  10      1        5.030368
# 5      15.984491   63.578186   11      1        4.610501
# 3     -160.851624  68.945145   12      1        4.483868
# 14     85.961830   51.922935   13      1        3.797653
# 10    -99.020836   109.936348  14      1        3.676156
# 15    -176.764130 -8.681684    15      1        2.907818
# ...

# %%
pyLDAvis.sklearn.prepare(nmf_model, cv_features, cv, mds='pcoa')
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.204105  0.027820  1       1        10.600774
# 17     0.101987  0.055596  2       1        9.391591
# 13    -0.005451 -0.005735  3       1        7.486701
# 8     -0.113121 -0.134680  4       1        7.366248
# 11    -0.177481  0.026300  5       1        6.050717
# 18    -0.160533 -0.088952  6       1        5.771450
# 6      0.071143  0.021852  7       1        5.762659
# 19    -0.015096  0.029520  8       1        5.655474
# 16    -0.065525  0.134047  9       1        5.310365
# 2      0.045810  0.141038  10      1        5.030368
# 5      0.069124  0.003284  11      1        4.610501
# 3      0.073528  0.112903  12      1        4.483868
# 14    -0.115265 -0.187487  13      1        3.797653
# 10     0.184878 -0.057771  14      1        3.676156
# 15    -0.174003 -0.124859  15      1        2.907818
# 9      0.103002  0.034880  16      1        2.787134
# ...
